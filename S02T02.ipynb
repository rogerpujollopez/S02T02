# %% [markdown]
# # S02T02 Estucrua d'una matriu

# %% [markdown]
# #### Exercici 1

# %%
import numpy as np
a = np.array([1, 2, 3, 6, 8, 20 , 4, 100])
print(a.shape)
print(a.size)
# Out:
# (8,)
# 8

# %% [markdown]
# #### Exercici 2

# %%
import statistics
import numpy as np
a = np.array([1, 2, 3, 6, 8, 20 , 4, 100])
mitja = statistics.mean(a)
print("Mitja: " + str(mitja))
a-=mitja
print(a)
# Out:
# Mitja: 18
# [-17 -16 -15 -12 -10   2 -14  82]

# %% [markdown]
# #### Exercici 3

# %%
import numpy as np
matriu = np.array([[5,8,10,20,1],[98,34,2,12,77],[41,87,12,61,89],[54,88,22,20,11],[90,80,70,60,50]])
print("Valor maxim matriu:" + str(matriu.max()))
print(np.amax(matriu,axis=1))
print(np.amax(matriu,axis=0))
# Out:
# Valor maxim matriu:98
# [20 98 89 88 90]
# [98 88 70 61 89]

# %% [markdown]
# #### Exercici 4

# %%
import numpy as np
a = np.array([1.0, 2.0, 3.0])
b = np.array([2.0, 2.0, 2.0])
c = np.array([3.0, 2.0, 1.0])
print (a * b * c)
# Out:
# [6. 8. 6.]

# %%
import numpy as np
a = np.array([1.0, 2.0, 3.0])
b = 2.0
print (a * b)
# Out:
# [2. 4. 6.]

# %% [markdown]
# #### Exercici 5

# %%
import numpy as np
matriu = np.array([[5,8,10,20,1],[98,34,2,12,77],[41,87,12,61,89],[54,88,22,20,11],[90,80,70,60,50]])
print(np.sum(matriu, axis=0))
print(np.sum(matriu, axis=1))
# Out:
# [288 297 116 173 228]
# [ 44 223 290 195 350]

# %% [markdown]
# #### Exercici 6

# %%
import numpy as np
matriu = np.array([[5,8,10,20,1],[98,34,2,12,77],[41,87,12,61,89],[54,88,22,20,11],[90,80,70,60,50]])
print(matriu%4 == 0)

# %% [markdown]
# #### Exercici 7

# %%
import numpy as np
matriu = np.array([[5,8,10,20,1],[98,34,2,12,77],[41,87,12,61,89],[54,88,22,20,11],[90,80,70,60,50]])
print(matriu[matriu%4 == 0])
# Out:
# [ 8 20 12 12 88 20 80 60]

# %% [markdown]
# #### Exercici 8

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("finques.jpg")

print(len(image)) #amplada
print(len(image[0])) # alçaca
print(len(image[0][0])) # pixel r g b

image[:,:,1]=0

plt.imshow(image)
plt.show()
mpimg.imsave("finquesNoGreen.jpg",image)
# Out:
# 5400
# 3600
# 3
